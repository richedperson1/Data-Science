# %%
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

# Generate a random dataset
X, y = make_classification(n_samples=100, n_features=2, n_classes=2, n_clusters_per_class=1, n_redundant=0, random_state=42)

# Fit logistic regression to the dataset
clf = LogisticRegression()
clf.fit(X, y)

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.RdBu)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu, edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundary for Logistic Regression')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Create or load your dataset
# X, y = ...
X, y12 = make_classification(n_samples=1000, n_classes=2, n_clusters_per_class=1, n_redundant=10, random_state=42,n_features=1)

X = X
# Train a logistic regression model
model = LogisticRegression()
model.fit(X, y12)

# Get the coefficients (m) and intercept (c)
coef = model.coef_
intercept = model.intercept_

coef

xMin,xMax = min(X),max(X)
x = np.linspace(xMin,xMax+5,20)
y = model.predict(x)

y_pred = model.predict(X)

m = model.coef_
c = model.intercept_

y_pred = m[0][0]*X + c
y_pred1 = m[0][0]*x + c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\ML and Python resource\Data science\ML model\logistic regression\logistic regression model.ipynb Cell 3 line 7
#       <a href='vscode-notebook-cell:/f%3A/ML%20and%20Python%20resource/Data%20science/ML%20model/logistic%20regression/logistic%20regression%20model.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.linear_model import LogisticRegression
#       <a href='vscode-notebook-cell:/f%3A/ML%20and%20Python%20resource/Data%20science/ML%20model/logistic%20regression/logistic%20regression%20model.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> # Create or load your dataset
#       <a href='vscode-notebook-cell:/f%3A/ML%20and%20Python%20resource/Data%20science/ML%20model/logistic%20regression/logistic%20regression%20model.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> # X, y = ...
# ...

# %%
X
# Out:
# array([[-0.42924442, -2.21186191,  0.18975576, ...,  0.94422366,
#         -0.26665233,  1.4017533 ],
#        [ 1.91200547, -0.05843012,  0.9457321 , ..., -0.54204507,
#         -0.05154221,  0.51467025],
#        [ 0.70745771,  0.78518508,  1.4758179 , ..., -0.86272945,
#         -0.23372406,  0.78234567],
#        ...,
#        [ 1.98363365, -0.08308933,  0.96579176, ..., -0.93462709,
#          2.45236991,  0.05565092],
#        [-0.992866  ,  0.51015747, -2.58266278, ...,  2.35389596,
#         -0.46913085, -0.32815344],
#        [-0.59662906,  0.30740357, -0.08918128, ...,  1.15496369,
#          1.19548065,  1.3126825 ]])

# %%
sns.lineplot(x = x.reshape(-1),y =y_pred1.reshape(-1))
plt.scatter(x = range(len(X)),y = X.reshape(-1,1))
plt.show()
# Out:
#   Cell In[67], line 2
#     plt.scatter(x = range(len(X)),X.reshape(-1,1))
#                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
df = pd.DataFrame({"col1":range(len(X)),"x":X.reshape(-1),"y":y12.reshape(-1)})

sns.scatterplot(df,x = "col1",y = "x",hue="y")
# Out:
# f:\set up\Anacoda\installation\envs\computerVision\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# f:\set up\Anacoda\installation\envs\computerVision\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# f:\set up\Anacoda\installation\envs\computerVision\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lineplot(x = range(len(x)),y = x.reshape(20));
plt.scatter(X,y_pred)
plt.show();
# Out:
# f:\set up\Anacoda\installation\envs\computerVision\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# f:\set up\Anacoda\installation\envs\computerVision\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# f:\set up\Anacoda\installation\envs\computerVision\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
