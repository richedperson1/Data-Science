# %%
import numpy as np
import numpy as np 
     
import matplotlib.pyplot as plt
import seaborn as sns
# from scipy import stats

# %%
import numpy as np

mu, sigma =50, 5
s = np.random.normal(mu, sigma, 10000)

a = lambda x : (x-mu)/sigma

# %%
print(np.std(s))
# Out:
# 5.0502008181721

# %%
np.std(list(map(a,s)))
# Out:
# 1.0100401636344203

# %%
sns.kdeplot(s)
plt.show()

sns.kdeplot(list(map(a,s)))
# Out:
# f:\set up\Anacoda\installation\envs\backendDjango\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# f:\set up\Anacoda\installation\envs\backendDjango\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# f:\set up\Anacoda\installation\envs\backendDjango\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.kdeplot(np.log(s))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the seed for reproducibility
np.random.seed(42)

# Generate random numbers from a log-normal distribution
mu = 5  # Mean of the underlying normal distribution
sigma = 3  # Standard deviation of the underlying normal distribution
size = 1000  # Number of samples
samples = np.random.lognormal(mu, sigma, size)

# Plot a histogram of the generated samples
sns.kdeplot(samples)
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Random Log-Normal Distribution')
plt.grid(True)

# Display the plot
plt.show()

# %%
z_scores = stats.zscore(samples)
sns.kdeplot(z_scores)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mu, sigma = 30., 0.01
  
s = np.random.lognormal(mu, sigma, 10000)
sns.kdeplot(s)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Min-Max scalling

# %%
# %pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 7.1/7.1 MB 9.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 298.0/298.0 kB 9.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()


mu, sigma =50, 2
s = np.random.normal(mu, sigma, 10000).reshape(-1, 1) 

data = scaler.fit_transform(s)
[np.std(data),np.mean(data)],[np.std(s),np.mean(s)]
# Out:
# ([0.12759000427091674, 0.4691048841190798],
#  [1.9966380561163444, 49.99277426378324])

# %%
sns.kdeplot(data)
# Out:
# <AxesSubplot:ylabel='Density'>
